# %% [markdown]
# # Problem Statement

# %% [markdown]
# To study the customer retention in Ecommerce websites.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
data = pd.read_excel(r"C:\Users\Swati\OneDrive\Desktop\DataScience\CustomerRetentionDataset_excel.xlsx")
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
print("No. of Rows : ",data.shape[0])
print("No. of Columns : ",data.shape[1])
pd.set_option('display.max_columns',None)
data.head()
# Out:
# No. of Rows :  269
# No. of Columns :  71
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# ...

# %% [markdown]
# # Let's check for Null Values

# %%
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# It means our dataset has no null values.

# %% [markdown]
# # Let's check for '-', ' ', 'NA', 'N/A', '?', ','

# %%
data.isin(['-', ' ', 'NA', 'N/A', '?', ',']).sum().sum()
# Out:
# 0

# %% [markdown]
# No other forms of missing values are present in the dataset

# %% [markdown]
# # Let's check for descriptive statistics

# %%
data.describe().T
# Out:
#                                                     count           mean  \
# 4 What is the Pin Code of where you shop online...  269.0  220465.747212
#
#                                                               std       min  \
# 4 What is the Pin Code of where you shop online...  140524.341051  110008.0
#
#                                                          25%       50%  \
# 4 What is the Pin Code of where you shop online...  122018.0  201303.0
#
#                                                          75%       max
# 4 What is the Pin Code of where you shop online...  201310.0  560037.0

# %%
data.describe(include=object).T
# Out:
#                                                    count unique  \
# 1Gender of respondent                                269      2
# 2 How old are you?                                   269      5
# 3 Which city do you shop online from?                269     11
# 5 Since How Long You are Shopping Online ?           269      5
# 6 How many times you have made an online purcha...   269      6
# ...                                                  ...    ...
# Longer delivery period                               269      6
# Change in website/Application design                 269      7
# Frequent disruption when moving from one page t...   269      8
# Website is as efficient as before                    269      8
# Which of the Indian online retailer would you r...   269      8
#
#                                                                    top freq
# 1Gender of respondent                                           Female  181
# ...

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(15,8))
f,ax = plt.subplots(1,2,figsize=(15,8))
data['1Gender of respondent'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])
plt.title("Gender of Respondent",fontsize=15)

sns.countplot('1Gender of respondent',data=data,ax=ax[1])
plt.xlabel('Gender',fontsize=15)
plt.ylabel('No. of Respondent',fontsize=15)
plt.title('Gender of Respondent',fontsize=15)

plt.show()

# %%
print("Percentage of Female Respondents :","66.91%")
print("Percentage of Male Respondents :","33.09%")
# Out:
# Percentage of Female Respondents : 66.91%
# Percentage of Male Respondents : 33.09%

# %% [markdown]
# It shows that Female respondents are more in count than that of Male respondents.
# It means that the percentage of online shopping is more in female than male

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['2 How old are you? '].value_counts().plot(kind="pie",autopct='%3.1f%%',ax=ax[0])

ax[0].set_title('Age of Respondent', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('2 How old are you? ',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('How old are Respondent',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Age of Respondent",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 30)
plt.show()
data['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 7.4% i.e. 20 respondents are form age group 'less than 20 years'.
# 2. 29.4% i.e 79 respondents are from age group '21-30 years'.
# 3. 30.1% i.e. 81 respondents are from age group '31-40 years'.
# 4. 26.0% i.e. 70 respondents are from age group '41-50 years'.
# 5. 7.1% i.e. 19 respondents are from age group '51 years and above'.
# `

# %% [markdown]
# More of the respondents are from age group '31-40 years' and '21-30 years'
# Less number of respondents are from age group '51 years and above' and 'less than 20 years'

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['5 Since How Long You are Shopping Online ?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Online Shopping Since(years)', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('5 Since How Long You are Shopping Online ?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Online Shopping Since(years)',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Online Shopping Since(years)",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 15.99% i.e. 43 respondents are doing online shopping since less than 1 years.
# 2. 5.95% i.e. 16 respondents are doing online shopping since last 1-2 years.
# 3. 24.16% i.e. 65 respondents are doing online shopping since last 2-3 years.'.
# 4. 17.47% i.e. 47 respondents are doing online shopping since last 3-4 years..
# 5. 36.43% i.e. 98 respondents are doing online shopping since above last 4 years.
# `

# %% [markdown]
# More of the respondents are doing online shopping since last 4& above years
# Less number of respondents are doing online shopping since last 1-2 years

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['3 Which city do you shop online from?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Online Shopping city', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('3 Which city do you shop online from?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Online Shopping Since(years)',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Online Shopping Since(years)",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. The highest percentage of Online shopping is from city "Delhi".
# 2. The lowest percentage of Online shopping are from cities "Bulandshahr" and "Moradabad".

# %%
data['6 How many times you have made an online purchase in the past 1 year?'] = data['6 How many times you have made an online purchase in the past 1 year?'].replace('42 times and above','41 times and above')

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['6 How many times you have made an online purchase in the past 1 year?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Total Online Shopping in past 1 year', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('6 How many times you have made an online purchase in the past 1 year?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Total Online Shopping in past 1 year',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Total Online Shopping in past 1 year",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 42.38% respondents made online shopping less than 10 times in past 1 year.
# 2. 23.42% respondents made online shopping 31-40 times in past 1 year.
# 3. 19.70% respondents made online shopping 41 times and above in past 1 year.
# 4. 10.78% respondents made online shopping  11-20 times in a past 1 year.
# 5. 3.72 respondents made online shopping 21-30 times in the past 1 year.

# %% [markdown]
# Most of the respondents made online shopping less than 10 times for the past 1 year.

# %%
data['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# We can see that in the internet access the Mobile Internet connection is been written in 2 different ways.
# So we will replace one of them by other.

# %%
data['7 How do you access the internet while shopping on-line?'] = data['7 How do you access the internet while shopping on-line?'].replace('Mobile internet','Mobile Internet')

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['7 How do you access the internet while shopping on-line?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Type of Internet Connection', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('7 How do you access the internet while shopping on-line?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Type of Internet Connection',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Internet Connection",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()

data['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 70.26% respondents made use of Mobile Internet for online shopping.
# 2. 28.25% respondents made use of Wi-Fi  for online shopping.
# 3. 1.49% respondents made use of Dial-up  for online shopping.

# %% [markdown]
# Majority of the respondents access the Mobile Internet while doing Online shopping.

# %% [markdown]
# The column titles from 9 to 13 are containing unnecessary spaces and '\t' so we will remove it by renaming the column titles

# %%
data.rename(columns= {'9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'9 What is the screen size of your mobile device?',
                   '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'10 What is the operating system (OS) of your device?',
                   '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'11 What browser do you run on your device to access the website?',
                   '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'12 Which channel did you follow to arrive at your favorite online store for the first time?',
                   '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'13 After first visit, how do you reach the online retail store?'},inplace=True)

# %% [markdown]
# # Let's make a list of features describing technical aspects

# %%
tech_aspects = ['7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?',
            '9 What is the screen size of your mobile device?','10 What is the operating system (OS) of your device?',
            '11 What browser do you run on your device to access the website?',
             '12 Which channel did you follow to arrive at your favorite online store for the first time?',
            '13 After first visit, how do you reach the online retail store?']

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['8 Which device do you use to access the online shopping?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Device used for Online Shopping', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('8 Which device do you use to access the online shopping?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Device used for Online Shopping',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Devices",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 52.42% respondents use Smartphones for online shopping.
# 2. 31.97% respondents use Laptop for online shopping.
# 3. 11.15% respondents use Desktop for online shopping.
# 4. 4.46% respondents use Tablet for online shopping.

# %% [markdown]
# Most of the respondents use smartphones for doing online shopping.
# The number of respondents using tablet for online shopping is very low.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['9 What is the screen size of your mobile device?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Screen Size of Mobile Device', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('9 What is the screen size of your mobile device?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Screen Size of Mobile Device',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Screen Size",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['9 What is the screen size of your mobile device?'].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 49.81% respondents have 'others' screen size of mobile device
# 2. 36.80% respondents have 5.5 inches screen size of mobile device.
# 3. 10.78% respondents have 4.7 inches screen size of mobile device.
# 4. 2.60% respondents have 5 inches screen size of mobile device.

# %% [markdown]
# More of the respondents have 'others' type screen size of mobile device.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['10 What is the operating system (OS) of your device?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Device OS', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('10 What is the operating system (OS) of your device?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Device OS',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Operating System",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['10 What is the operating system (OS) of your device?'].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 45.35% respondents have Window/windows Mobile OS for device.
# 2. 31.60% respondents have Android OS for device.
# 3. 23.05% respondents have IOS/Mac OS for device.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['11 What browser do you run on your device to access the website?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Browser to access the website', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('11 What browser do you run on your device to access the website?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Browser to access the website',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Browser",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['11 What browser do you run on your device to access the website?'].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 80.30% respondents use Google chrome browser for online shopping.
# 2. 14.87% respondents use Safari browser for online shopping.
# 3. 2.97% respondents use Opera  browser for online shopping.
# 4. 1.86% respondents use Mozilla Firefox  browser for online shopping.

# %% [markdown]
# Majority of the respondents use Google chrome browser for online shopping.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['12 Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Channel to arrive Online Store', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('12 Which channel did you follow to arrive at your favorite online store for the first time?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Channel to arrive Online Store',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Channel",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['12 Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 85.50% respondents use Search Engine channel to arrive at your favorite online store.
# 2. 7.43% respondents use Content Marketing channel to arrive at your favorite online store.
# 3. 7.06% respondents use Display Adverts channel to arrive at your favorite online store.

# %% [markdown]
# The chennel used maximum times to arrive at favorite online store is Search Engine channel

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['13 After first visit, how do you reach the online retail store?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('How do you reach Online Retail Store', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('13 After first visit, how do you reach the online retail store?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('How do you reach Online Retail Store',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("How do you reach Online Retail Store",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['13 After first visit, how do you reach the online retail store?'].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 32.34% respondents use Search Engine to reach Online Store after first visit.
# 2. 31.97% respondents reach Online Store Via application after first visit.
# 3. 26.02% respondents reach Online Store by  Direct URL after first visit.
# 4. 6.69% respondents reach Online Store through E-mail after first visit.
# 5. 2.97% respondents use Social Media to reach Online Store after first visit.

# %% [markdown]
# Majority of respondents reach online store through 'Search Engine' and 'Via application' after first visit and
# very less respondents use 'Social Media'.

# %% [markdown]
# # Purchase Desicison & Payment related features

# %%
data.rename(columns ={'14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'14 How much time do you explore the e- retail store before making a purchase decision?',
                   '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'15 What is your preferred payment Option?',
                   '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',
                   '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'17 Why did you abandon the “Bag”, “Shopping Cart”?'},inplace= True)

# %%
Purchase_payment = ['14 How much time do you explore the e- retail store before making a purchase decision?',
             '15 What is your preferred payment Option?',
             '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',
             '17 Why did you abandon the “Bag”, “Shopping Cart”?']

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['14 How much time do you explore the e- retail store before making a purchase decision?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Explore e-retail before purchse', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('3 Which city do you shop online from?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Explore e-retail before purchse',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Explore e-retail before purchse",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['14 How much time do you explore the e- retail store before making a purchase decision?'].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 45.72% respondents take More than 15 minutes to take a purchase decision.
# 2. 26.39% respondents take 6-10 minutes to take a purchase decision.
# 3. 17.10% respondents take 11-15 minutes to take a purchase decision.
# 4. 5.58% respondents take less than 1 min to take a purchase decision.
# 5. 5.20% respondents take 1-5 minutes to take a purchase decision.

# %% [markdown]
# Most of the respondents explores more than 15 minutes before making a purchase decision.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['15 What is your preferred payment Option?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Preferred Payment Method', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('15 What is your preferred payment Option?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Preferred Payment Method',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Payment Methods",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['15 What is your preferred payment Option?'].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 55.02% respondents considers using Credit/Debit cards as a preferred payment method.
# 2. 28.25% respondents choose Cash on Delivery (CoD) as preferred payment method.
# 3. 16.73% respondents make payment through E-wallets (Paytm, Freecharge etc.)

# %% [markdown]
# Credit/Debit cards payment method is highly preferred

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Abandon Shopping Cart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Abandon Shopping Cart',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Abandon Shopping Cart",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 63.57% respondents abandon their cart sometimes.
# 2. 17.84% respondents never abandon their cart.
# 3. 13% respondents abandon their cart Frequently.
# 4. 5.58% respondents abandon their cart Very Frequently.

# %% [markdown]
# Most of the respondents abandon their cart for sometimes.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['17 Why did you abandon the “Bag”, “Shopping Cart”?'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Reason for Abandon Shopping Cart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('17 Why did you abandon the “Bag”, “Shopping Cart”?',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Reason for Abandon Shopping Cart',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Reasons",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['17 Why did you abandon the “Bag”, “Shopping Cart”?'].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 50% respondents leave the cart for Better alternative offer.
# 2. 20% respondents leave the cart because of Promo code not applicable.
# 3. 13.75% respondents leave the cart due to Change in price.
# 4. 12% respondents leave the cart for Lack of trust.
# 5. 5% respondents leave the cart due to No preferred mode of payment.

# %% [markdown]
# #  Website Usability & performance related feature

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['18 The content on the website must be easy to read and understand'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Easy Website Content', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('18 The content on the website must be easy to read and understand',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Easy Website Content',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 61% respondents are strongly agreed that The content on the website must be easy to read and understand
# 2. 30% are agreed that The content on the website must be easy to read and understand
# 3. 7% respondents are strongly disagreed that The content on the website must be easy to read and understand
# 4. 2.60% respondents are  Indifferent  for The content on the website must be easy to read and understand

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Necessity of Highlighted Information', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('19 Information on similar product to the one highlighted  is important for product comparison',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Necessity of Highlighted Information',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 43.12% respondents are strongly agreed for Necessity of highlighted information for product comparison
# 2. 30.20% respondents are agreed for Necessity of highlighted information for product comparison
# 3. 16% respondents are Indifferent about Necessity of highlighted information for product comparison
# 4. 6.69% respondents are Dis-agreed for Necessity of highlighted information for product comparison

# %% [markdown]
# most of the respondents are strongly agrees for Information on similar product to the one highlighted  is important for product comparison

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Information on listed seller and product', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('20 Complete information on listed seller and product being offered is important for purchase decision.',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Information on listed seller and product',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 37.55% respondents Agreed that Complete information on listed seller and product being offered is important for purchase        decision
# 2. 32.34% respondents strongly Agreed that Complete information on listed seller and product being offered is important for        purchase decision
# 3. 19.33% respondents are Indifferent about their opinoin.
# 4. 6.69% respondents are dis-agreed on Complete information on listed seller and product being offered is important for purchase    decision
# 5. 4.09% respondents are strongly is-agreed on Complete information on listed seller and product being offered is important for    purchase decision

# %% [markdown]
# 70% respondents are agreed on Complete information on listed seller and product being offered is important for purchase mdecision

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['21 All relevant information on listed products must be stated clearly'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Information on listed product must be clearly stated', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('21 All relevant information on listed products must be stated clearly',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Information on listed product must be clearly stated',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 49.07% respondents are agreed that All relevant information on listed products must be stated clearly.
# 2. 39.78% respondents are strongly agreed that All relevant information on listed products must be stated clearly
# 3. 6.69% respondents are strongly dis-agreed on All relevant information on listed products must be stated clearly
# 4. 4.46% respondents are dis-agreed on All relevant information on listed products must be stated clearly

# %% [markdown]
# Near about 90% of the respondents are agreed on All relevant information on listed products must be stated clearly.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['22 Ease of navigation in website'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Ease of navigation', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('22 Ease of navigation in website',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Ease of navigation',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 52.42% respondents are strongly agree for Ease of navigation in website.
# 2. 39% respondents are agree for Ease of navigation in website.
# 3. 6.69% respondents are strongly disagree for Ease of navigation in website.
# 4. 1.86% respondents are disagree for Ease of navigation in website.

# %% [markdown]
# Near about 91% respondents agreed on Ease of navigation in website.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['23 Loading and processing speed'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Loading and processing speed', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('23 Loading and processing speed',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Loading and processing speed',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 42.75% respondents are strongly agree for Loading and processing speed.
# 2. 41.64% respondents are agree for Loading and processing speed.
# 3. 6.69% respondents are  disagree for Loading and processing speed.
# 4. 4.46% respondents are strongly disagree for Loading and processing speed.
# 5. 4.46% respondents are Indifferent about their opinion for Loading and processing speed.

# %% [markdown]
# Near about 85% respondents agreed for Loading and processing speed.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['24 User friendly Interface of the website'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('User friendly Interface of website', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('24 User friendly Interface of the website',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('User friendly Interface of website',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 70.26% respondents are strongly agree for User friendly Interface of the website.
# 2. 16.73% respondents are agree for User friendly Interface of the website.
# 3. 6.69% respondents are strongly disagree for User friendly Interface of the website.
# 4. 4.46% respondents are  disagree for User friendly Interface of the website.
# 5. 1.86% respondents are Indifferent about their opinion for User friendly Interface of the website.

# %% [markdown]
# Near about 87% respondents agreed for User friendly Interface of the website.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['25 Convenient Payment methods'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Convenient Payment methods', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('25 Convenient Payment methods',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Convenient Payment methods',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 59.11% respondents are strongly agree for Convenient Payment methods.
# 2. 29.74% respondents are agree for Convenient Payment methods.
# 3. 11.15% respondents are disagree for Convenient Payment methods.

# %% [markdown]
# Near about 89% respondents agreed for Convenient Payment methods.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Convenient Payment methods', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Convenient Payment methods',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# # Online shopping store customer service requirement related features

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['27 Empathy (readiness to assist with queries) towards the customers'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Empathy towards the customers', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('27 Empathy (readiness to assist with queries) towards the customers',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Empathy towards the customers',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 72.12% respondents are strongly agree for Empathy (readiness to assist with queries) towards the customers.
# 2. 15.61% respondents are agree for Empathy (readiness to assist with queries) towards the customers.
# 3. 6.69% respondents are strongly disagree for Empathy (readiness to assist with queries) towards the customers.
# 4. 5.58% respondents are indifferent about their opinion for Empathy (readiness to assist with queries) towards the customers.

# %% [markdown]
# Near about 88% respondents agreed for Empathy (readiness to assist with queries) towards the customers.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['28 Being able to guarantee the privacy of the customer'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Privacy Guarantee', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('28 Being able to guarantee the privacy of the customer',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Privacy Guarantee',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 68.77% respondents strongly agreed on Being able to guarantee the privacy of the customer.
# 2. 21.56% respondents agreed on Being able to guarantee the privacy of the customer.
# 3. 9.67% respondents are indifferent about their opinion on Being able to guarantee the privacy of the customer.

# %% [markdown]
# Near about 90% respondents agreed on Being able to guarantee the privacy of the customer.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Responsiveness and availability of several communication channels', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Responsivenessa and availability of several communication channels',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 55.39% respondents strongly agreed on Responsiveness, availability of several communication channels.
# 2. 34.94% respondents agreed on Responsiveness, availability of several communication channels.
# 3. 5.58% respondents are indifferent about their opinion on Responsiveness, availability of several communication channels.
# 4. 4.09% respondents strongly dis-agreed on Responsiveness, availability of several communication channels.

# %% [markdown]
# Near about 90% respondents agreed on respondents agreed on Responsiveness, availability of several communication channels.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['30 Online shopping gives monetary benefit and discounts'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Benefit and Discounts', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('30 Online shopping gives monetary benefit and discounts',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Benefit and Discounts',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 39.03% respondents strongly agreed that Online shopping gives monetary benefit and discounts.
# 2. 31.60% respondents agreed Online shopping gives monetary benefit and discounts.
# 3. 18.59% respondents are indifferent about their opinion that Online shopping gives monetary benefit and discounts.
# 4. 6.69% respondents strongly dis-agreed that Online shopping gives monetary benefit and discounts.
# 5. 4.09 % respondents dis-agreed that Online shopping gives monetary benefit and discounts.

# %% [markdown]
# Near about 70% respondents agreed that Online shopping gives monetary benefit and discounts.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['31 Enjoyment is derived from shopping online'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Enjoyment from online shopping', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('31 Enjoyment is derived from shopping online',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Enjoyment from online shopping',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 31.97% respondents strongly agreed that Enjoyment is derived from shopping online.
# 2. 27.88% respondents are indifferent about their opinion that Enjoyment is derived from shopping online.
# 3. 21.93% respondents agreed  that Enjoyment is derived from shopping online..
# 4. 11.15% respondents strongly dis-agreed that Enjoyment is derived from shopping online..
# 5. 7.06 % respondents dis-agreed that Enjoyment is derived from shopping online..

# %% [markdown]
# Near about 60% respondents agreed that Enjoyment is derived from shopping online..

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['32 Shopping online is convenient and flexible'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Convenience and Flexibility', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('32 Shopping online is convenient and flexible',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Convenience and Flexibility',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 54.28% respondents strongly agreed that Online Shopping is convenient and flexible.
# 2. 29% respondents agreed that Online Shopping is convenient and flexible.
# 3. 12.27% respondents are infifferent about their opinion that Online Shopping is convenient and flexible.
# 4. 4.46% respondents dis-agreed that Online Shopping is convenient and flexible.

# %% [markdown]
# Near about 83% respondents agreed that Online Shopping is convenient and flexible.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Return and replacement policy', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('33 Return and replacement policy of the e-tailer is important for purchase decision',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Return and replacement policy',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 73.61% respondents strongly agreed that Return and replacement policy of the e-tailer is important for purchase decision.
# 2. 18.96% respondents agreed that Return and replacement policy of the e-tailer is important for purchase decision.
# 3. 7.43% respondents dis-agreed that Return and replacement policy of the e-tailer is important for purchase decision.

# %% [markdown]
# Near about 93% respondents agreed that Online Shopping is convenient and flexible.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Gaining access to loyalty programs', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('34 Gaining access to loyalty programs is a benefit of shopping online',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Gaining access to loyalty programs',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 42.75% respondents strongly agreed that Gaining access to loyalty programs is a benefit of shopping online.
# 2. 23.79% respondents agreed that Gaining access to loyalty programs is a benefit of shopping online.
# 3. 4.09% respondents strongly dis-agreed that Gaining access to loyalty programs is a benefit of shopping online.
# 4. 5.58% respondents dis-agreed that Gaining access to loyalty programs is a benefit of shopping online.
# 5. 23.79% respondents are indifferent abput their opinion that Gaining access to loyalty programs is a benefit of shopping          online.

# %% [markdown]
# Near about 67% respondents agreed that Online Shopping is convenient and flexible.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Quality Information Display', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('35 Displaying quality Information on the website improves satisfaction of customers',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Quality Information Display',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 49.44% respondents strongly agreed that Displaying quality Information on the website improves satisfaction of customers.
# 2. 29.74% respondents agreed that Displaying quality Information on the website improves satisfaction of customers.
# 3. 20.82% respondents are indifferent abput their opinion that Displaying quality Information on the website improves              satisfaction of customers.

# %% [markdown]
# Near about 80% respondents agreed that Displaying quality Information on the website improves satisfaction of customers.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['36 User derive satisfaction while shopping on a good quality website or application'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Website or Application', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('36 User derive satisfaction while shopping on a good quality website or application',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Website or Application',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 30)
plt.show()
data['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 65% respondents strongly agreed that User derive satisfaction while shopping on a good quality website or application.
# 2. 32% respondents agreed that User derive satisfaction while shopping on a good quality website or application.
# 3. 3% respondents dis-agreed that User derive satisfaction while shopping on a good quality website or application.

# %% [markdown]
# Near about 97% respondents agreed that User derive satisfaction while shopping on a good quality website or application.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Net Benefit', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('37 Net Benefit derived from shopping online can lead to users satisfaction',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Net Benefit',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 61% respondents strongly agreed that Net Benefit derived from shopping online can lead to users satisfaction.
# 2. 20% respondents agreed that Net Benefit derived from shopping online can lead to users satisfaction.
# 3. 4% respondents dis-agreed that Net Benefit derived from shopping online can lead to users satisfaction.
# 4. 15% respondents are indifferent abput their opinion that Net Benefit derived from shopping online can lead to users              satisfaction.

# %% [markdown]
# Near about 71% respondents agreed that Net Benefit derived from shopping online can lead to users satisfaction.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['38 User satisfaction cannot exist without trust'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('User satisfaction', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('38 User satisfaction cannot exist without trust',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('User satisfaction',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 45.35% respondents strongly agreed that User satisfaction cannot exist without trust.
# 2. 43.49% respondents agreed that User satisfaction cannot exist without trust.
# 3. 6.69% respondents strongly dis-agreed that User satisfaction cannot exist without trust.
# 4. 2.60% respondents dis-agreed that User satisfaction cannot exist without trust.
# 5. 1.86% respondents are indifferent abput their opinion that User satisfaction cannot exist without trust.

# %% [markdown]
# Near about 88% respondents agreed that User satisfaction cannot exist without trust.

# %% [markdown]
# # feature related to Customer online shopping experiences

# %%
Feature_5 = ['39 Offering a wide variety of listed product in several category','40 Provision of complete and relevant product information',
            '41 Monetary savings','42 The Convenience of patronizing the online retailer','43 Shopping on the website gives you the sense of adventure',
            '44 Shopping on your preferred e-tailer enhances your social status','45 You feel gratification shopping on your favorite e-tailer',
            '46 Shopping on the website helps you fulfill certain roles','47 Getting value for money spent']

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['39 Offering a wide variety of listed product in several category'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Offering a wide variety of listed product in several category', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('39 Offering a wide variety of listed product in several category',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Offering a wide variety of listed product in several category',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 41.26% respondents strongly agreed on Offering a wide variety of listed product in several category.
# 2. 34.94% respondents agreed on Offering a wide variety of listed product in several category.
# 3. 2.60% respondents dis-agreed on Offering a wide variety of listed product in several category.
# 4. 21.96% respondents are indifferent abput their opinion on Offering a wide variety of listed product in several category.

# %% [markdown]
# Near about 75% respondents agreed that Offering a wide variety of listed product in several category.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['40 Provision of complete and relevant product information'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Provision of complete and relevant product information', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('40 Provision of complete and relevant product information',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Provision of complete and relevant product information',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 50.19% respondents strongly agreed for Provision of complete and relevant product information.
# 2. 36.43% respondents agreed for Provision of complete and relevant product information.
# 3. 1.86% respondents dis-agreed for Provision of complete and relevant product information.
# 4. 11.52% respondents are indifferent abput their opinion for Provision of complete and relevant product information.

# %% [markdown]
# Near about 86% respondents agreed for Provision of complete and relevant product information.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['41 Monetary savings'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Monetary savings', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('41 Monetary savings',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Monetary savings',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 55% respondents strongly agreed for Monetary savings.
# 2. 28% respondents agreed for Monetary savings.
# 3. 11.52% respondents dis-agreed for Monetary savings.
# 4. 5.58% respondents are indifferent abput their opinion for Monetary savings.

# %% [markdown]
# Near about 83% respondents agreed for Monetary savings.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['42 The Convenience of patronizing the online retailer'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Convenience of patronizing the online retailer', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('42 The Convenience of patronizing the online retailer',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Convenience of patronizing the online retailer',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 30)
plt.show()
data['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 20.07% respondents strongly agreed for The Convenience of patronizing the online retailer.
# 2. 51.30% respondents agreed for The Convenience of patronizing the online retailer.
# 3. 28.62% respondents are indifferent abput their opinion for The Convenience of patronizing the online retailer.

# %% [markdown]
# Near about 71% respondents agreed for The Convenience of patronizing the online retailer.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['43 Shopping on the website gives you the sense of adventure'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('sense of adventure', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('43 Shopping on the website gives you the sense of adventure',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('sense of adventure',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 20.07% respondents strongly agreed that Shopping on the website gives you the sense of adventure.
# 2. 37.55% respondents agreed that Shopping on the website gives you the sense of adventure.
# 3. 21.93% respondents are indifferent abput their opinion that Shopping on the website gives you the sense of adventure.
# 4. 1.86% respondents strongly dis-agreed that Shopping on the website gives you the sense of adventure.
# 5. 18.59% respondents dis-agreed that Shopping on the website gives you the sense of adventure.

# %% [markdown]
# Near about 58% respondents agreed for The Convenience of patronizing the online retailer.

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['44 Shopping on your preferred e-tailer enhances your social status'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('social status', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('44 Shopping on your preferred e-tailer enhances your social status',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('social status',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 17.84% respondents strongly agreed that Shopping on your preferred e-tailer enhances your social status.
# 2. 21.93% respondents agreed that Shopping on your preferred e-tailer enhances your social status.
# 3. 37.17% respondents are indifferent abput their opinion that Shopping on your preferred e-tailer enhances your social status.
# 4. 12.27% respondents strongly dis-agreed that Shopping on your preferred e-tailer enhances your social status.
# 5. 10.78% respondents dis-agreed that Shopping on your preferred e-tailer enhances your social status.

# %% [markdown]
# Near about 40% respondents agreed that Shopping on your preferred e-tailer enhances your social status

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['45 You feel gratification shopping on your favorite e-tailer'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Gratification', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('45 You feel gratification shopping on your favorite e-tailer',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Gratification',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 24.16% respondents strongly agreed that they feel gratification shopping on their favorite e-tailer.
# 2. 23.42% respondents agreed that they feel gratification shopping on their favorite e-tailer.
# 3. 37.55% respondents are indifferent abput their opinion that they feel gratification shopping on their favorite e-tailer.
# 4. 6.69% respondents strongly dis-agreed that they feel gratification shopping on their favorite e-tailer.
# 5. 8.18% respondents dis-agreed that they feel gratification shopping on their favorite e-tailer.

# %% [markdown]
# Near about 48% respondents agreed that they feel gratification shopping on their favorite e-tailer

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['46 Shopping on the website helps you fulfill certain roles'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('fulfill certain roles', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('46 Shopping on the website helps you fulfill certain roles',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('fulfill certain roles',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 14.13% respondents strongly agreed that Shopping on the website helps you fulfill certain roles.
# 2. 32.71% respondents agreed that Shopping on the website helps you fulfill certain roles.
# 3. 32.71% respondents are indifferent abput their opinion that Shopping on the website helps you fulfill certain roles.
# 4. 12.27% respondents strongly dis-agreed that Shopping on the website helps you fulfill certain roles.
# 5. 8.18% respondents dis-agreed that Shopping on the website helps you fulfill certain roles.

# %% [markdown]
# Near about 47% respondents agreed that they feel gratification shopping on their favorite e-tailer

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))

data['47 Getting value for money spent'].value_counts().plot(kind="pie",autopct='%1.2f%%',ax=ax[0])

ax[0].set_title('Getting value for money spent', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('47 Getting value for money spent',hue =data['1Gender of respondent'] , data=data,ax=ax[1])
ax[1].set_title('Getting value for money spent',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Respondnet Opinion",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 90)
plt.show()
data['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# # Observations

# %% [markdown]
# 1. 30.48% respondents strongly agreed for Getting value for money spent.
# 2. 55.39% respondents agreed for Getting value for money spent.
# 3. 14.13% respondents are indifferent abput their opinion for Getting value for money spent.

# %% [markdown]
# Near about 85% respondents agreed for Getting value for money spent.

# %% [markdown]
# # Opinion on Online Shopping Platform Websites by Customer

# %%
data.rename(columns= {'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':
                   'From the following, tick any (or all) of the online retailers you have shopped from'},inplace=True)

# %%
Opinion_features = [
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ']

# %%
plt.figure(figsize=(12,120))
plotnumber =1
for i in Opinion_features:
    if plotnumber <=12:
        ax = plt.subplot(10,1,plotnumber)
        sns.countplot(data[i])
        plt.title(i,fontsize=15,fontweight ='bold')
        plt.xticks(rotation=90)
        plt.ylabel('')
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation :

# %% [markdown]
# 1. Majority customers agree that Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com are Easy to use website or            application. But Overall if we look at countplot of easy to use application & website Amazon.in got individually 1st Rank.
# 2. 87 customers agree that Amazon.in, Flipkart.com have Visual appealing web-page layout than most of other market players.
# 3. Around according to 125 people Amazon.in, Flipkart.com provides wide varity of offer on product.
# 4. We already know 50.2% Strongly agree over providing complete relevalent product information, and here we can see that 100        customer think that Amazon.in, Flipkart.com provides complete information compare to others.
# 5. Previously we know that 42.8 % customer strongly agree and 41.6 % customer agree over high loading & processing speed of        website.Here we can see Majority of people think that loading speed of Amazon.in is fastest while Flipkart.com slowest          website to load.
# 6. In terms of Reliability of website or application again Amazon top list.
# 7. Majority of people also think that Amazon.in tops the chart in terms of quickness purchase process compare to others.
# 8. Majority of customers think that Amazon.in, Flipkart.com provides several payment options compare to others.
# 9. Safe & Speed delivery very much deciding factor in terms of purchase. In terms of speed of delivery Amazon.in is much better    than other online shopping platform and Flipkart.com worst among all in terms of speed delivery of product.

# %% [markdown]
# # Privacy & Security Related Features

# %%
privacy_security = ['Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?']

# %%
plt.figure(figsize=(12,150))
plotnumber =1
for i in privacy_security:
    if plotnumber <=14:
        ax = plt.subplot(14,1,plotnumber)
        sns.countplot(data[i])
        plt.title(i,fontsize=20,fontweight ='bold')
        plt.xticks(rotation=90)
        plt.ylabel('')
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation :

# %% [markdown]
# 1. We already Know more than 90% Customer thinks that gaurantee on privacy of thier information is important for them.Majority      of customers trust Amazon.in more than other shopping platform for Privacy of customers’ information
# 2. Majority of customer trust Amazon.in followed by Flipkart.in over Security of thier financial information.We also see very      few peoples trust payment platform paytm.
# 3. Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com provide assistance through different multi channel.
# 4. Longer time to get logged in can annoyed customer. *Amazon.in take longer time to logged in while Flipkart.com take least        time among all*.
# 5. Majority of people agree that Amazon.in, Flipkart.com takes longer time in displaying and photos.
# 6. Myntra.com followed by Paytm.com take longer page loading time.
# 7. Most of people want shorter delivery time frame, majority customer agree that Paytm.com takes longest time for delivery          compare to others.
# 8. Amazon.in website is as effient as ealier after updation.
# 9. Majority 80 peoples recommanded Amazon.in to their friends.

# %% [markdown]
# # Label Encoding

# %%
 from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data = data.apply(le.fit_transform)
data.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      1                    1
# 1                      0                    0
# 2                      0                    0
# 3                      1                    0
# 4                      0                    0
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                                  1
# 1                                                  5
# 2                                                 23
# 3                                                 11
# 4                                                 31
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           3
# ...

# %%
data.corr()['Which of the Indian online retailer would you recommend to a friend?'].sort_values()
# Out:
# 31 Enjoyment is derived from shopping online                            -0.436613
# 34 Gaining access to loyalty programs is a benefit of shopping online   -0.400583
# 21 All relevant information on listed products must be stated clearly   -0.362879
# 28 Being able to guarantee the privacy of the customer                  -0.358734
# 18 The content on the website must be easy to read and understand       -0.349016
#                                                                            ...
# Presence of online assistance through multi-channel                      0.503836
# Easy to use website or application                                       0.541713
# Reliability of the website or application                                0.542711
# Complete, relevant description information of products                   0.680926
# Which of the Indian online retailer would you recommend to a friend?     1.000000
# ...
